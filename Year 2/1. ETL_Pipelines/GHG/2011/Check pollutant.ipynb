# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('onroad_5.csv')
df
# Out:
# C:\Users\zapate\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#         state_and_county_fips_code  tribal_name st_usps_cd county_name  \
# 0                            39077          NaN         OH       Huron
# 1                            26107          NaN         MI     Mecosta
# 2                            39153          NaN         OH      Summit
# 3                            26083          NaN         MI    Keweenaw
# 4                            18057          NaN         IN    Hamilton
# ...                            ...          ...        ...         ...
# 533890                       18145          NaN         IN      Shelby
# 533891                       18143          NaN         IN       Scott
# 533892                       17167          NaN         IL    Sangamon
# ...

# %%
df['description'].unique()
# Out:
# array(['Ethyl Benzene', 'Styrene', '1,3-Butadiene', 'Acrolein', 'Toluene',
#        'Hexane', 'Anthracene', 'Propionaldehyde', 'Pyrene',
#        'Xylenes (Mixed Isomers)', 'Chromium (VI)',
#        'Benzo[g,h,i,]Perylene', 'Indeno[1,2,3-c,d]Pyrene',
#        'Benzo[b]Fluoranthene', 'Fluoranthene', 'Benzo[k]Fluoranthene',
#        'Acenaphthylene', 'Chrysene', 'Formaldehyde', 'Benzo[a]Pyrene',
#        'Dibenzo[a,h]Anthracene', '2,2,4-Trimethylpentane',
#        'Benz[a]Anthracene', 'Benzene', 'Manganese', 'Mercury', 'Nickel',
#        'Arsenic', 'Acetaldehyde', 'Acenaphthene', 'Phenanthrene',
#        'Fluorene', 'Naphthalene', 'Methane', 'Carbon Monoxide',
#        'Carbon Dioxide', 'Nitrous Oxide', 'Ammonia', 'Nitrogen Oxides',
#        'PM10 Primary (Filt + Cond)', 'PM2.5 Primary (Filt + Cond)',
#        'Sulfur Dioxide', 'Volatile Organic Compounds'], dtype=object)

# %%
df[df['description'].isin(['Methane', 'Carbon Dioxide'])]
# Out:
#         state_and_county_fips_code  tribal_name st_usps_cd county_name  \
# 409437                       18131          NaN         IN     Pulaski
# 409438                       26029          NaN         MI  Charlevoix
# 409439                       18091          NaN         IN    La Porte
# 409440                       55141          NaN         WI        Wood
# 409441                       17191          NaN         IL       Wayne
# ...                            ...          ...        ...         ...
# 446455                       18049          NaN         IN      Fulton
# 446456                       17049          NaN         IL   Effingham
# 446457                       18105          NaN         IN      Monroe
# 446458                       27161          NaN         MN      Waseca
# 446459                       39085          NaN         OH        Lake
#
#        data_category_cd         scc  emissions_type_code  \
# ...
