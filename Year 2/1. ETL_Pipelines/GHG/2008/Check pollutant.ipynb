# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('2008NEIv3_onroad8910.csv', nrows = 5000000)
df
# Out:
# C:\Users\zapate\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#          state_and_county_fips_code  tribal_name st_usps_cd       county_name  \
# 0                              4001          NaN         AZ            Apache
# 1                              2290          NaN         AK     Yukon-Koyukuk
# 2                             32031          NaN         NV            Washoe
# 3                              4015          NaN         AZ            Mohave
# 4                              2188          NaN         AK  Northwest Arctic
# ...                             ...          ...        ...               ...
# 2249925                       46023          NaN         SD       Charles Mix
# 2249926                       49033          NaN         UT              Rich
# ...

# %%
df['description'].unique()
# Out:
# array(['Ethyl Benzene', 'Styrene', 'p-Xylene', '1,3-Butadiene',
#        'Acrolein', 'm-Xylene', 'Toluene', 'Hexane', 'Anthracene',
#        'Propionaldehyde', 'Pyrene', 'PAH, total',
#        'Xylenes (Mixed Isomers)', 'Chromium III', 'Chromium (VI)',
#        'Benzo[g,h,i,]Perylene', 'Indeno[1,2,3-c,d]Pyrene',
#        'Benzo[b]Fluoranthene', 'Fluoranthene', 'Benzo[k]Fluoranthene',
#        'Acenaphthylene', 'Chrysene', 'Formaldehyde', 'Benzo[a]Pyrene',
#        'Dibenzo[a,h]Anthracene', '2,2,4-Trimethylpentane',
#        'Benz[a]Anthracene', 'Methanol', 'Benzene', 'Lead', 'Manganese',
#        'Mercury', 'Nickel', 'Antimony', 'Arsenic', 'Cadmium', 'Cobalt',
#        'Acetaldehyde', 'Phosphorus', 'Selenium', 'Chlorine',
#        'Acenaphthene', 'Phenanthrene', 'Fluorene', 'Naphthalene',
#        '2-Methylnaphthalene', 'o-Xylene', 'Cumene', 'Methane',
#        'Carbon Monoxide', 'Carbon Dioxide', 'Nitrous Oxide', 'Ammonia',
# ...
