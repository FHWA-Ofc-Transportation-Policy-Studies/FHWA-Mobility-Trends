# %%
import pandas as pd

# %%
df = pd.read_csv('onroad_123.csv')
df.head()
# Out:
#    epa region code state  fips state code  tribal name  fips code     county  \
# 0                1    MA               25          NaN      25027  Worcester
# 1                1    MA               25          NaN      25027  Worcester
# 2                1    MA               25          NaN      25027  Worcester
# 3                1    MA               25          NaN      25027  Worcester
# 4                1    MA               25          NaN      25027  Worcester
#
#   data category  emissions type code         scc  \
# 0            ON                  NaN  2202530080
# 1            ON                  NaN  2202530080
# 2            ON                  NaN  2202530080
# 3            ON                  NaN  2202530080
# 4            ON                  NaN  2202530080
#
#                                         sector  aetc reporting period  \
# 0  Mobile - On-Road Diesel Heavy Duty Vehicles   NaN                A
# 1  Mobile - On-Road Diesel Heavy Duty Vehicles   NaN                A
# 2  Mobile - On-Road Diesel Heavy Duty Vehicles   NaN                A
# 3  Mobile - On-Road Diesel Heavy Duty Vehicles   NaN                A
# 4  Mobile - On-Road Diesel Heavy Duty Vehicles   NaN                A
#
#   emissions operating type pollutant code         pollutant desc  \
# 0                        R         100414          Ethyl Benzene
# 1                        R         108883                Toluene
# 2                        R         120127             Anthracene
# 3                        R         191242  Benzo[g,h,i,]Perylene
# 4                        R        7439965              Manganese
#
#   pollutant type(s)  total emissions emissions uom         data set
# 0               HAP        33.169620            LB  2017NEI_Apr2020
# 1               HAP        76.188060            LB  2017NEI_Apr2020
# 2               HAP         3.508804            LB  2017NEI_Apr2020
# 3               HAP         0.050601            LB  2017NEI_Apr2020
# 4               HAP         0.457772            LB  2017NEI_Apr2020

# %%
def sum_pollutants(df_title):
    df123 = pd.read_csv(df_title)
    df123 = df123[['fips code','pollutant desc', 'total emissions']]
    df123 = df123[df123['pollutant desc'].isin(['Methane','Carbon Dioxide'])]
    df123_summed = df123.groupby(['fips code']).sum('total emissions')
    df123_summed = df123_summed.reset_index()
    
    return df123_summed

df_title_list = ['onroad_123.csv','onroad_4.csv','onroad_5.csv','onroad_67.csv', 'onroad_8910.csv']


final_df = None
for i in df_title_list:
    df_summed = sum_pollutants(i)
    if final_df is None:
        final_df = df_summed
    else:
        final_df = pd.concat([final_df, df_summed], axis = 0)

# %%
final_df['YEAR'] = 2017
final_df.head()
# Out:
#    fips code  total emissions  YEAR
# 0       9001     3.581312e+06  2017
# 1       9003     3.699414e+06  2017
# 2       9005     6.053314e+05  2017
# 3       9007     7.962074e+05  2017
# 4       9009     3.351824e+06  2017

# %%
len(final_df)
# Out:
# 3227

# %%
final_df.groupby('fips code').count().sort_values(by='total emissions', ascending = False)
# Out:
#            total emissions  YEAR
# fips code
# 1001                     1     1
# 40049                    1     1
# 40029                    1     1
# 40031                    1     1
# 40033                    1     1
# ...                    ...   ...
# 21171                    1     1
# 21173                    1     1
# 21175                    1     1
# 21177                    1     1
# 88183                    1     1
#
# [3227 rows x 2 columns]

# %%
final_df.to_csv('COUNTY_GHG_2017.csv', index = True)

# %% [markdown]
# OLD

# %%
df123 = pd.read_csv('2008NEIv3_onroad123.csv')
'''
df4 = pd.read_csv('2008NEIv3_onroad4.csv')
df4['YEAR'] = 2008

df5 = pd.read_csv('2008NEIv3_onroad5.csv')
df5['YEAR'] = 2008

df67 = pd.read_csv('2008NEIv3_onroad67.csv')
df67['YEAR'] = 2008

df8910 = pd.read_csv('2008NEIv3_onroad8910.csv')
df8910['YEAR'] = 2008
'''
# Out:
# C:\Users\zapate\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# "\ndf4 = pd.read_csv('2008NEIv3_onroad4.csv')\ndf4['YEAR'] = 2008\n\ndf5 = pd.read_csv('2008NEIv3_onroad5.csv')\ndf5['YEAR'] = 2008\n\ndf67 = pd.read_csv('2008NEIv3_onroad67.csv')\ndf67['YEAR'] = 2008\n\ndf8910 = pd.read_csv('2008NEIv3_onroad8910.csv')\ndf8910['YEAR'] = 2008\n"

# %%
df123 = df123[['state_and_county_fips_code','description', 'total_emissions']]
df123 = df123[df123['description'].isin(['Methane','Carbon Dioxide'])]

df123_summed = df123.groupby(['state_and_county_fips_code']).sum('total_emissions')

# %%
df123_summed.reset_index()
# Out:
#      state_and_county_fips_code  total_emissions
# 0                          9001     4.132524e+06
# 1                          9003     4.219697e+06
# 2                          9005     6.749110e+05
# 3                          9007     9.179930e+05
# 4                          9009     3.858755e+06
# ..                          ...              ...
# 510                       72151     1.365024e+05
# 511                       72153     2.078118e+04
# 512                       78010     8.745828e+04
# 513                       78020     7.698858e+03
# 514                       78030     9.055935e+04
#
# [515 rows x 2 columns]

# %%
df123.groupby('state_and_county_fips_code').count()
# Out:
#                             description  total_emissions
# state_and_county_fips_code
# 9001                                288              288
# 9003                                288              288
# 9005                                264              264
# 9007                                288              288
# 9009                                312              312
# ...                                 ...              ...
# 72151                               312              312
# 72153                               168              168
# 78010                               240              240
# 78020                               240              240
# 78030                               240              240
#
# [515 rows x 2 columns]
