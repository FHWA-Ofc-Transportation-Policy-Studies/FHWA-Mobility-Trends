# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
#checking lane miles if on same scale
df = pd.read_csv('VMT_MODELING_DATASET7_6.csv').drop(columns = ['Unnamed: 0']).drop_duplicates().dropna()
df
# Out:
#        STATE_CODE  COUNTY_CODE  YEAR           VMT POPULATION      GDP  \
# 14562           1          1.0  2005   322993600.0    49676.0  1195319
# 14563           1          3.0  2005  1340591700.0   162183.0  5502688
# 14564           1          5.0  2005   137144980.0    28027.0   892271
# 14565           1          7.0  2005   107760790.0    22042.0   322815
# 14566           1          9.0  2005   219522450.0    54624.0   887578
# ...           ...          ...   ...           ...        ...      ...
# 63828          56         37.0  2020   807080640.0     42,190  3344988
# 63829          56         39.0  2020   173860200.0     23,377  2308166
# 63830          56         41.0  2020   268234400.0     20,457   785684
# 63831          56         43.0  2020    49651270.0      7,658   345111
# 63832          56         45.0  2020    56497024.0      6,818   292568
#
#       Unemployment_Rate  Charging_Stations   LNMILES       TMS  TELEWORK  \
# ...

# %%
df.dtypes
# Out:
# STATE_CODE             int64
# COUNTY_CODE          float64
# YEAR                   int64
# VMT                   object
# POPULATION            object
# GDP                   object
# Unemployment_Rate     object
# Charging_Stations    float64
# LNMILES              float64
# TMS                  float64
# TELEWORK             float64
# distributed_UPT      float64
# GEMS_Typo             object
# USDA_UIC             float64
# dtype: object

# %%
df['VMT'] = pd.to_numeric(df['VMT'].str.replace(',',''), errors = 'coerce')
df['POPULATION'] = pd.to_numeric(df['POPULATION'].str.replace(',',''), errors = 'coerce')
df['POPULATION'] = pd.to_numeric(df['POPULATION'].str.replace(',',''), errors = 'coerce')
df['GDP'] = pd.to_numeric(df['GDP'].str.replace(',',''), errors = 'coerce')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "[nan]"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23856\824089843.py in <module>
# ----> 1 df['VMT'] = pd.to_numeric(df['VMT'])
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\tools\numeric.py in to_numeric(arg, errors, downcast)
#     181         coerce_numeric = errors not in ("ignore", "raise")
#     182         try:
# --> 183             values, _ = lib.maybe_convert_numeric(
#     184                 values, set(), coerce_numeric=coerce_numeric
#     185             )
#
# ...
